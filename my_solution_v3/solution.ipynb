# %% [markdown]
# # Zindi Liquidity Stress Solution V3
#
# This notebook runs the packaged `v3_auto` solution and writes the submission file to `submissions/submission.csv`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import solution

solution.main()

# %%
from pathlib import Path
import pandas as pd

submission_path = Path('submissions/submission.csv')
summary_path = Path('run_summary_v3_auto.json')

print(f'Submission file: {submission_path.resolve()}')
print(f'Run summary: {summary_path.resolve()}')
print(pd.read_csv(submission_path).head())
